# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
xpoints=np.array([0,10])
ypoints=np.array([0,250])
plt.plot(xpoints,ypoints)
plt.show()

# %%
plt.plot(xpoints,ypoints,'yo')
plt.show()

# %%
xpoints=np.array([1,3,5,7,9])
ypoints=np.array([2,4,3,8,5])
plt.plot(xpoints,ypoints)
plt.show()

# %%
plt.plot(ypoints ,"o:m")
plt.show()

# %% [markdown]
# ## Line Style and Line Colour

# %%
plt.plot(ypoints,ls="--",c="y")

# %%
plt.plot(ypoints,ls="--",c="y",linewidth='10')

# %%
plt.plot(xpoints, ypoints)

plt.title("Sports Watch Data")
plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")

plt.show()

# %%
plt.plot(ypoints)
plt.grid()
plt.show()

# %%
plt.plot(np.array([2,3,4,1,6,7,12,3,9,10]))
plt.grid(axis='y',c="g")
plt.show()

# %%
plt.scatter(xpoints,ypoints,c="r")
plt.show()
